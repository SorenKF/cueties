# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
from collections import defaultdict
#import glob

# %%
df = pd.read_csv('./../../Data/parc_features/parc_train_features.tsv', delimiter='\t', index_col=0)

# %%
df.loc[df['attribution'] != '0'].loc[df['attribution'] != '_ _ _ _ _ _ _ _ _ _ _ _ _'].loc[df['attribution'] != '_ _ _ _ _ _']
# Out:
#          POS  dependency_head dependency_label  doc_token_number  \
# 57        DT                2              det                 1
# 58        NN               13            nsubj                 2
# 59        IN                4             case                 3
# 60        NN                2             nmod                 4
# 61        RB                6           advmod                 5
# 62       VBD               35            ccomp                 6
# 63        TO                8             mark                 7
# 64        VB                6            xcomp                 8
# 65       NNP               11         compound                 9
# 66        NN               11         compound                10
# 67       NNS                8              obj                11
# 68       VBZ               13              aux                12
# 69       VBN                6            xcomp                13
# 70        DT               16              det                14
# 71        JJ               16             amod                15
# 72        NN               13              obj                16
# 73        IN               19             case                17
# 74        NN               19         compound                18
# 75       NNS               16             nmod                19
# 76        IN               22             case                20
# 77        DT               22              det                21
# 78        NN               16             nmod                22
# 79        IN               24             case                23
# 80       NNS               22             nmod                24
# 81       VBN               24              acl                25
# 82        IN               27             case                26
# 83       PRP               25              obl                27
# 84       JJR               30           advmod                28
# 85        IN               28            fixed                29
# 86        CD               31           nummod                30
# 87       NNS               32        obl:npmod                31
# 88        RB               25           advmod                32
# 90       NNS               35            nsubj                34
# 91       VBD                0             root                35
# 93        DT                3              det                37
# 94        NN                3         compound                38
# 95        NN                9            nsubj                39
# 96         ,                3            punct                40
# 97        NN                3            appos                41
# 98         ,                9            punct                42
# 99       VBZ                9              cop                43
# 100       RB                9           advmod                44
# 101       JJ               31            ccomp                45
# 102       IN               12             mark                46
# 103      PRP               12            nsubj                47
# 104      VBZ                9            advcl                48
# 105       DT               14              det                49
# 106      NNS               12              obj                50
# 107        ,               12            punct                51
# 108       IN               19             case                52
# ...      ...              ...              ...               ...
# 1066655   RB               10           advmod               511
# 1066656    ,               17            punct               512
# 1066657   ''               17            punct               513
# 1066658  NNP               17            nsubj               514
# 1066659  NNP               15             flat               515
# 1066660  VBZ                0             root               516
# 1066681  NNP                3            nsubj               537
# 1066682  NNP                1             flat               538
# 1066683  VBZ                0             root               539
# 1066684  PRP                7             expl               540
# 1066685   MD                7              aux               541
# 1066686   VB                7              cop               542
# 1066687  JJR                3            ccomp               543
# 1066688   TO                9             mark               544
# 1066689   VB                7            csubj               545
# 1066690  NNP                9              obj               546
# 1066691  NNP               10             flat               547
# 1066692   RB                9           advmod               548
# 1066693   IN               21             mark               549
# 1066694  PRP               21            nsubj               550
# 1066695  VBZ               21              cop               551
# 1066696   RB               21           advmod               552
# 1066697   IN               21             case               553
# 1066698   DT               19              det               554
# 1066699   NN               21        nmod:poss               555
# 1066700  POS               19             case               556
# 1066701   NN                9            advcl               557
# 1066703  WRB                3             mark               559
# 1066704  PRP                3            nsubj               560
# 1066705  VBD               23            ccomp               561
# 1066706   TO                5             mark               562
# 1066707  VBN                3            xcomp               563
# 1066708    ,               23            punct               564
# 1066709   ``               11            punct               565
# 1066710  PRP               11            nsubj               566
# 1066711  VBD               11              aux               567
# 1066712   RB               11           advmod               568
# 1066713   VB               23            ccomp               569
# 1066714   DT               13              det               570
# 1066715   NN               11              obj               571
# 1066716   TO               15             mark               572
# 1066717   VB               13              acl               573
# 1066718   IN               18             mark               574
# 1066719  PRP               18            nsubj               575
# 1066720  VBP               15            advcl               576
# 1066721   NN               18         obl:tmod               577
# 1066722    ,               23            punct               578
# 1066723   ''               23            punct               579
# 1066724  PRP               23            nsubj               580
# 1066725  VBZ                0             root               581
#
#                   lemma   ne_info  sentence_number  sentence_token_number  \
# 57                    a         O                1                      1
# 58                 form         O                1                      2
# 59                   of         O                1                      3
# 60              asbesto         O                1                      4
# 61                 once         O                1                      5
# 62                  use         O                1                      6
# 63                   to         O                1                      7
# 64                 make         O                1                      8
# 65                 Kent     S-GPE                1                      9
# 66            cigarette         O                1                     10
# 67               filter         O                1                     11
# 68                 have         O                1                     12
# 69                cause         O                1                     13
# 70                    a         O                1                     14
# 71                 high         O                1                     15
# 72           percentage         O                1                     16
# 73                   of         O                1                     17
# 74               cancer         O                1                     18
# 75                death         O                1                     19
# 76                among         O                1                     20
# 77                    a         O                1                     21
# 78                group         O                1                     22
# 79                   of         O                1                     23
# 80               worker         O                1                     24
# 81               expose         O                1                     25
# 82                   to         O                1                     26
# 83                   it         O                1                     27
# 84                 more    B-DATE                1                     28
# 85                 than    I-DATE                1                     29
# 86                   30    I-DATE                1                     30
# 87                 year    I-DATE                1                     31
# 88                  ago    E-DATE                1                     32
# 90           researcher         O                1                     34
# 91               report         O                1                     35
# 93                  the         O                2                      1
# 94              asbesto         O                2                      2
# 95                fiber         O                2                      3
# 96                    ,         O                2                      4
# 97          crocidolite         O                2                      5
# 98                    ,         O                2                      6
# 99                   be         O                2                      7
# 100           unusually         O                2                      8
# 101           resilient         O                2                      9
# 102                once         O                2                     10
# 103                  it         O                2                     11
# 104               enter         O                2                     12
# 105                 the         O                2                     13
# 106                lung         O                2                     14
# 107                   ,         O                2                     15
# 108                with         O                2                     16
# ...                 ...       ...              ...                    ...
# 1066655  satisfactorily         O               21                     12
# 1066656               ,         O               21                     13
# 1066657              ''         O               21                     14
# 1066658             Mr.         O               21                     15
# 1066659             Sim  S-PERSON               21                     16
# 1066660             say         O               21                     17
# 1066681             Mr.         O               23                      1
# 1066682             Sim  S-PERSON               23                      2
# 1066683          figure         O               23                      3
# 1066684              it         O               23                      4
# 1066685            will         O               23                      5
# 1066686              be         O               23                      6
# 1066687          easier         O               23                      7
# 1066688              to         O               23                      8
# 1066689            turn         O               23                      9
# 1066690           Barry  B-PERSON               23                     10
# 1066691          Wright  E-PERSON               23                     11
# 1066692          around         O               23                     12
# 1066693           since         O               23                     13
# 1066694              he         O               23                     14
# 1066695              be         O               23                     15
# 1066696             now         O               23                     16
# 1066697              in         O               23                     17
# 1066698             the         O               23                     18
# 1066699          driver         O               23                     19
# 1066700              's         O               23                     20
# 1066701            seat         O               23                     21
# 1066703            when         O               24                      1
# 1066722               ,          0                _ _ _ I-CONTENT-PD-5 _ _
# 1066723              ''          0                _ _ _ I-CONTENT-PD-5 _ _
# 1066724              he          0                 _ _ _ B-SOURCE-PD-5 _ _
# 1066725            says          1                    _ _ _ B-CUE-PD-5 _ _
#
#                token_-1        token_-2        token_-3        token_-4  \
# 57                    .               .               .               .
# 58                    A               .               .               .
# 59                 form               A               .               .
# 60                   of            form               A               .
# 61             asbestos              of            form               A
# 62                 once        asbestos              of            form
# 63                 used            once        asbestos              of
# 64                   to            used            once        asbestos
# 65                 make              to            used            once
# 66                 Kent            make              to            used
# 67            cigarette            Kent            make              to
# 68              filters       cigarette            Kent            make
# 69                  has         filters       cigarette            Kent
# 70               caused             has         filters       cigarette
# 71                    a          caused             has         filters
# 72                 high               a          caused             has
# 73           percentage            high               a          caused
# 74                   of      percentage            high               a
# 75               cancer              of      percentage            high
# 76               deaths          cancer              of      percentage
# 77                among          deaths          cancer              of
# 78                    a           among          deaths          cancer
# 79                group               a           among          deaths
# 80                   of           group               a           among
# 81              workers              of           group               a
# 82              exposed         workers              of           group
# 83                   to         exposed         workers              of
# 84                   it              to         exposed         workers
# 85                 more              it              to         exposed
# 86                 than            more              it              to
# 87                   30            than            more              it
# 88                years              30            than            more
# 90                    ,             ago           years              30
# 91          researchers               ,             ago           years
# 93                    .        reported     researchers               ,
# 94                  The               .        reported     researchers
# 95             asbestos             The               .        reported
# 96                fiber        asbestos             The               .
# 97                    ,           fiber        asbestos             The
# 98          crocidolite               ,           fiber        asbestos
# 99                    ,     crocidolite               ,           fiber
# 100                  is               ,     crocidolite               ,
# 101           unusually              is               ,     crocidolite
# 102           resilient       unusually              is               ,
# 103                once       resilient       unusually              is
# 104                  it            once       resilient       unusually
# 105              enters              it            once       resilient
# 106                 the          enters              it            once
# 107               lungs             the          enters              it
# 108                   ,           lungs             the          enters
# ...                 ...             ...             ...             ...
# 1066655            very         perform            will      businesses
# 1066656  satisfactorily            very         perform            will
# 1066657               ,  satisfactorily            very         perform
# 1066658              ''               ,  satisfactorily            very
# 1066659             Mr.              ''               ,  satisfactorily
# 1066660             Sim             Mr.              ''               ,
# 1066681               .        predicts              he              ''
# 1066682             Mr.               .        predicts              he
# 1066683             Sim             Mr.               .        predicts
# 1066684         figures             Sim             Mr.               .
# 1066685              it         figures             Sim             Mr.
# 1066686            will              it         figures             Sim
# 1066687              be            will              it         figures
# 1066688          easier              be            will              it
# 1066689              to          easier              be            will
# 1066690            turn              to          easier              be
# 1066691           Barry            turn              to          easier
# 1066692          Wright           Barry            turn              to
# 1066693          around          Wright           Barry            turn
# 1066694           since          around          Wright           Barry
# 1066695              he           since          around          Wright
# 1066696              's              he           since          around
# 1066697             now              's              he           since
# 1066698              in             now              's              he
# 1066699             the              in             now              's
# 1066700          driver             the              in             now
# 1066701              's          driver             the              in
# 1066703               .            seat              's          driver
# 1066704            When               .            seat              's
# 1066705              he            When               .            seat
# 1066706            came              he            When               .
# 1066707              to            came              he            When
# 1066708         Applied              to            came              he
# 1066709               ,         Applied              to            came
# 1066710              ``               ,         Applied              to
# 1066711               I              ``               ,         Applied
# 1066712             did               I              ``               ,
# 1066713             n't             did               I              ``
# 1066714            have             n't             did               I
# 1066715             the            have             n't             did
# 1066716           power             the            have             n't
# 1066717              to           power             the            have
# 1066718         execute              to           power             the
# 1066719              as         execute              to           power
# 1066720               I              as         execute              to
# 1066721              do               I              as         execute
# 1066722           today              do               I              as
# 1066723               ,           today              do               I
# 1066724              ''               ,           today              do
# 1066725              he              ''               ,           today
#
#                token_-5     token_+1     token_+2     token_+3     token_+4  \
# 57                    .         form           of     asbestos         once
# 58                    .           of     asbestos         once         used
# 59                    .     asbestos         once         used           to
# 60                    .         once         used           to         make
# 61                    .         used           to         make         Kent
# 62                    A           to         make         Kent    cigarette
# 63                 form         make         Kent    cigarette      filters
# 64                   of         Kent    cigarette      filters          has
# 65             asbestos    cigarette      filters          has       caused
# 66                 once      filters          has       caused            a
# 67                 used          has       caused            a         high
# 68                   to       caused            a         high   percentage
# 69                 make            a         high   percentage           of
# 70                 Kent         high   percentage           of       cancer
# 71            cigarette   percentage           of       cancer       deaths
# 72              filters           of       cancer       deaths        among
# 73                  has       cancer       deaths        among            a
# 74               caused       deaths        among            a        group
# 75                    a        among            a        group           of
# 76                 high            a        group           of      workers
# 77           percentage        group           of      workers      exposed
# 78                   of           of      workers      exposed           to
# 79               cancer      workers      exposed           to           it
# 80               deaths      exposed           to           it         more
# 81                among           to           it         more         than
# 82                    a           it         more         than           30
# 83                group         more         than           30        years
# 84                   of         than           30        years          ago
# 85              workers           30        years          ago            ,
# 86              exposed        years          ago            ,  researchers
# 87                   to          ago            ,  researchers     reported
# 88                   it            ,  researchers     reported            .
# 90                 than     reported            .          The     asbestos
# 91                   30            .          The     asbestos        fiber
# 93                  ago     asbestos        fiber            ,  crocidolite
# 94                    ,        fiber            ,  crocidolite            ,
# 95          researchers            ,  crocidolite            ,           is
# 96             reported  crocidolite            ,           is    unusually
# 97                    .            ,           is    unusually    resilient
# 98                  The           is    unusually    resilient         once
# 99             asbestos    unusually    resilient         once           it
# 100               fiber    resilient         once           it       enters
# 101                   ,         once           it       enters          the
# 102         crocidolite           it       enters          the        lungs
# 103                   ,       enters          the        lungs            ,
# 104                  is          the        lungs            ,         with
# 105           unusually        lungs            ,         with         even
# 106           resilient            ,         with         even        brief
# 107                once         with         even        brief    exposures
# 108                  it         even        brief    exposures           to
# ...                 ...          ...          ...          ...          ...
# 1066655           these            ,           ''          Mr.          Sim
# 1066656      businesses           ''          Mr.          Sim         says
# 1066657            will          Mr.          Sim         says            .
# 1066658         perform          Sim         says            .       Within
# 1066659            very         says            .       Within        about
# 1066660  satisfactorily            .       Within        about          six
# 1066681               ,          Sim      figures           it         will
# 1066682              ''      figures           it         will           be
# 1066683              he           it         will           be       easier
# 1066684        predicts         will           be       easier           to
# 1066685               .           be       easier           to         turn
# 1066686             Mr.       easier           to         turn        Barry
# 1066687             Sim           to         turn        Barry       Wright
# 1066688         figures         turn        Barry       Wright       around
# 1066689              it        Barry       Wright       around        since
# 1066690            will       Wright       around        since           he
# 1066691              be       around        since           he           's
# 1066692          easier        since           he           's          now
# 1066693              to           he           's          now           in
# 1066694            turn           's          now           in          the
# 1066695           Barry          now           in          the       driver
# 1066696          Wright           in          the       driver           's
# 1066697          around          the       driver           's         seat
# 1066698           since       driver           's         seat            .
# 1066699              he           's         seat            .         When
# 1066700              's         seat            .         When           he
# 1066701             now            .         When           he         came
# 1066703             the           he         came           to      Applied
# 1066704          driver         came           to      Applied            ,
# 1066705              's           to      Applied            ,           ``
# 1066706            seat      Applied            ,           ``            I
# 1066707               .            ,           ``            I          did
# 1066708            When           ``            I          did          n't
# 1066709              he            I          did          n't         have
# 1066710            came          did          n't         have          the
# 1066711              to          n't         have          the        power
# 1066712         Applied         have          the        power           to
# 1066713               ,          the        power           to      execute
# 1066714              ``        power           to      execute           as
# 1066715               I           to      execute           as            I
# 1066716             did      execute           as            I           do
# 1066717             n't           as            I           do        today
# 1066718            have            I           do        today            ,
# 1066719             the           do        today            ,           ''
# 1066720           power        today            ,           ''           he
# 1066721              to            ,           ''           he         says
# 1066722         execute           ''           he         says            .
# 1066723              as           he         says            .           He
# 1066724               I         says            .           He          was
# 1066725              do            .           He          was        named
#
#             token_+5        lemma_-1        lemma_-2        lemma_-3  \
# 57              used               .               .               .
# 58                to               a               .               .
# 59              make            form               a               .
# 60              Kent              of            form               a
# 61         cigarette         asbesto              of            form
# 62           filters            once         asbesto              of
# 63               has             use            once         asbesto
# 64            caused              to             use            once
# 65                 a            make              to             use
# 66              high            Kent            make              to
# 67        percentage       cigarette            Kent            make
# 68                of          filter       cigarette            Kent
# 69            cancer            have          filter       cigarette
# 70            deaths           cause            have          filter
# 71             among               a           cause            have
# 72                 a            high               a           cause
# 73             group      percentage            high               a
# 74                of              of      percentage            high
# 75           workers          cancer              of      percentage
# 76           exposed           death          cancer              of
# 77                to           among           death          cancer
# 78                it               a           among           death
# 79              more           group               a           among
# 80              than              of           group               a
# 81                30          worker              of           group
# 82             years          expose          worker              of
# 83               ago              to          expose          worker
# 84                 ,              it              to          expose
# 85       researchers            more              it              to
# 86          reported            than            more              it
# 87                 .              30            than            more
# 88               The            year              30            than
# 90             fiber               ,             ago            year
# 91                 ,      researcher               ,             ago
# 93                 ,               .          report      researcher
# 94                is             the               .          report
# 95         unusually         asbesto             the               .
# 96         resilient           fiber         asbesto             the
# 97              once               ,           fiber         asbesto
# 98                it     crocidolite               ,           fiber
# 99            enters               ,     crocidolite               ,
# 100              the              be               ,     crocidolite
# 101            lungs       unusually              be               ,
# 102                ,       resilient       unusually              be
# 103             with            once       resilient       unusually
# 104             even              it            once       resilient
# 105            brief           enter              it            once
# 106        exposures             the           enter              it
# 107               to            lung             the           enter
# 108               it               ,            lung             the
# ...              ...             ...             ...             ...
# 1066655         says            very         perform            will
# 1066656            .  satisfactorily            very         perform
# 1066657       Within               ,  satisfactorily            very
# 1066658        about              ''               ,  satisfactorily
# 1066659          six             Mr.              ''               ,
# 1066660       months             Sim             Mr.              ''
# 1066681           be               .         predict              he
# 1066682       easier             Mr.               .         predict
# 1066683           to             Sim             Mr.               .
# 1066684         turn          figure             Sim             Mr.
# 1066685        Barry              it          figure             Sim
# 1066686       Wright            will              it          figure
# 1066687       around              be            will              it
# 1066688        since          easier              be            will
# 1066689           he              to          easier              be
# 1066690           's            turn              to          easier
# 1066691          now           Barry            turn              to
# 1066692           in          Wright           Barry            turn
# 1066693          the          around          Wright           Barry
# 1066694       driver           since          around          Wright
# 1066695           's              he           since          around
# 1066696         seat              be              he           since
# 1066697            .             now              be              he
# 1066698         When              in             now              be
# 1066699           he             the              in             now
# 1066700         came          driver             the              in
# 1066701           to              's          driver             the
# 1066703            ,               .            seat              's
# 1066704           ``            when               .            seat
# 1066705            I              he            when               .
# 1066706          did            come              he            when
# 1066707          n't              to            come              he
# 1066708         have           apply              to            come
# 1066709          the               ,           apply              to
# 1066710        power              ``               ,           apply
# 1066711           to               I              ``               ,
# 1066712      execute              do               I              ``
# 1066713           as             not              do               I
# 1066714            I            have             not              do
# 1066715           do             the            have             not
# 1066716        today           power             the            have
# 1066717            ,              to           power             the
# 1066718           ''         execute              to           power
# 1066719           he              as         execute              to
# 1066720         says               I              as         execute
# 1066721            .              do               I              as
# 1066722           He           today              do               I
# 1066723          was               ,           today              do
# 1066724        named              ''               ,           today
# 1066725        chief              he              ''               ,
#
#                lemma_-4        lemma_-5     lemma_+1     lemma_+2  \
# 57                    .               .         form           of
# 58                    .               .           of      asbesto
# 59                    .               .      asbesto         once
# 60                    .               .         once          use
# 61                    a               .          use           to
# 62                 form               a           to         make
# 63                   of            form         make         Kent
# 64              asbesto              of         Kent    cigarette
# 65                 once         asbesto    cigarette       filter
# 66                  use            once       filter         have
# 67                   to             use         have        cause
# 68                 make              to        cause            a
# 69                 Kent            make            a         high
# 70            cigarette            Kent         high   percentage
# 71               filter       cigarette   percentage           of
# 72                 have          filter           of       cancer
# 73                cause            have       cancer        death
# 74                    a           cause        death        among
# 75                 high               a        among            a
# 76           percentage            high            a        group
# 77                   of      percentage        group           of
# 78               cancer              of           of       worker
# 79                death          cancer       worker       expose
# 80                among           death       expose           to
# 81                    a           among           to           it
# 82                group               a           it         more
# 83                   of           group         more         than
# 84               worker              of         than           30
# 85               expose          worker           30         year
# 86                   to          expose         year          ago
# ...
# 1066693           O0           O1           O0  wsj_2282.tsv
# 1066694           O0           O1           O0  wsj_2282.tsv
# 1066695           O0           O1           O0  wsj_2282.tsv
# 1066696           O0           O1           O0  wsj_2282.tsv
# 1066697           O0           O1           O0  wsj_2282.tsv
# 1066698           O0           O1           O0  wsj_2282.tsv
# 1066699           O0           O1           O0  wsj_2282.tsv
# 1066700           O0           O1           O0  wsj_2282.tsv
# 1066701           O0           O1           O0  wsj_2282.tsv
# 1066703           O0           O1           O0  wsj_2282.tsv
# 1066704           O0           O1           O0  wsj_2282.tsv
# 1066705           O0           O1           O0  wsj_2282.tsv
# 1066715                   32                   10                1
# 1066716                   33                    9                1
# 1066717                   34                    8                1
# 1066718                   35                    7                1
# 1066719                   36                    6                1
# 1066720                   37                    5                1
# 1066721                   38                    4                1
# 1066722                   39                    3                1
# 1066723                   40                    2                1
# 1066724                   41                    1                1
# 1066725                    0                    0                1
#
# [941869 rows x 73 columns]

# %%
df.loc[57, 'attribution'].strip('_ ').strip(' ').split('-')[0]
# Out:
# 'B'

# %%
df['attribution_list'] = df.loc[df['attribution'] != '0'].loc[df['attribution'] != '_ _ _ _ _ _ _ _ _ _ _ _ _'].loc[df['attribution'] != '_ _ _ _ _ _']['attribution'].apply(lambda x: x.strip('_ ').strip(' ').split('-'))

# %%
df.loc[df['attribution_list'] == 0, 'attribution_list'] = [0, 0, 0, 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-ac6390c5f21c> in <module>
# ----> 1 df.loc[df['attribution_list'] == 0, 'attribution_list'] = [0, 0, 0, 0]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     609
#     610                     if len(labels) != len(value):
# --> 611                         raise ValueError('Must have equal len keys and value '
#     612                                          'when setting with an iterable')
#     613
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
glob.glob('./../../Data/parc_features/parc_train_features.tsv')
# Out:
# ['./../../Data/parc_features\\parc_dev_features.tsv',
#  './../../Data/parc_features\\parc_test_features.tsv',
#  './../../Data/parc_features\\parc_test_predicted_features.tsv',
#  './../../Data/parc_features\\parc_train_features.tsv']

# %%
# file_list = glob.glob('./../../Data/parc/parc_dev_pred_set/*')
# # Read all files and join in one huge df
# df = pd.read_csv(file_list[0], delimiter='\t', index_col=0)
# for filename in file_list[1:]:
#     df_temp = pd.read_csv(filename, delimiter='\t', index_col=0)
#     df = pd.concat([df, df_temp], ignore_index=True)

# %%
df.columns
# Out:
# Index(['POS', 'dependency_head', 'dependency_label', 'doc_token_number',
#        'lemma', 'ne_info', 'sentence_number', 'sentence_token_number', 'token',
#        'cue_label', 'token_-1', 'token_-2', 'token_-3', 'token_-4', 'token_-5',
#        'token_+1', 'token_+2', 'token_+3', 'token_+4', 'token_+5', 'lemma_-1',
#        'lemma_-2', 'lemma_-3', 'lemma_-4', 'lemma_-5', 'lemma_+1', 'lemma_+2',
#        'lemma_+3', 'lemma_+4', 'lemma_+5', 'POS_-1', 'POS_-2', 'POS_-3',
#        'POS_-4', 'POS_-5', 'POS_+1', 'POS_+2', 'POS_+3', 'POS_+4', 'POS_+5',
#        'bigram_prev_token', 'bigram_prev_lemma', 'bigram_prev_POS',
#        'bigram_following_token', 'bigram_following_lemma',
#        'bigram_following_POS', 'shape', 'ne_short', 'relevant_ne', 'ne_+-5',
#        'candidate_cue', 'reporting_verb', 'quotation', 'near_sent_boundary',
#        'near_doc_boundary', 'dist_beg_sent', 'dist_end_sent', 'sent_len',
#        'pn_in_sent', 'ne_in_sent', 'qm_in_sent', 'any_in_sent', 'quotation_pn',
#        'quotation_ne', 'quotation_qm', 'filename', 'ancestor_is_cue',
#        'cue_in_window_of_5', 'distance_to_prev_cue', 'distance_to_next_cue',
#        'cue_in_sentence', 'content_label_gold', 'content_label_pred'],
#       dtype='object')

# %% [markdown]
# ## What do we want to find?
#
# - How many potential sources in sentences with contents?
# - How often is there only one source in the sent?
# - How often is the source in the sent of the content?
# - How often is the source in adjacent sentences?
# - How long are the sources? Pronoun vs NE?

# %% [markdown]
# ### What did Nathan find?
#
# Total sources that are not relevant NEs: 37777
# Total sources: 60513
# Total sources that are any type of NE: 23845
# Total sources that are NOT any type of NE: 36668
# Total sources that are pronouns: 3570
#
# - 37.6% of the sources are a relevant NEs (22736/60513)
# - 39.4% of the sources are any NE (23845/60513)
# - 5.9% of the sources are a pronoun (3570/60513)
# - Meaning 45.3% of the sources are an NE or pronoun, which is less than half

# %%
1 - 37777/60513
# Out:
# 0.37572091947184905

# %%
(23845 + 3570)/60513
# Out:
# 0.4530431477533753

# %%
df.loc[df['token']=='it']
# Out:
#        POS  dependency_head dependency_label  doc_token_number lemma ne_info  \
# 127    PRP               23       nsubj:pass               128    it       O
# 210    PRP               10       nsubj:pass               211    it       O
# 966    PRP                6              obj               305    it       O
# 986    PRP               14              obl               325    it       O
# 1259   PRP               23              obj               598    it       O
# 1286   PRP                3             expl               625    it       O
# 1466   PRP               34              obj               805    it       O
# 1580   PRP               15              obj               919    it       O
# 1587   PRP               21             nmod               926    it       O
# 1646   PRP                3              obj               985    it       O
# 2398   PRP               17            nsubj               487    it       O
# 2405   PRP               25            nsubj               494    it       O
# 2528   PRP               17              obj               617    it       O
# 2753   PRP               16            nsubj               217    it       O
# 3442   PRP               22              obj               138    it       O
# 3696   PRP               28       nsubj:pass               392    it       O
# 3735   PRP               19            nsubj               431    it       O
# 4005   PRP               21            nsubj               701    it       O
# 4503   PRP                5       nsubj:pass                68    it       O
# 4581   PRP                3             expl               146    it       O
# 4734   PRP               21       nsubj:pass               299    it       O
# 4742   PRP                4             expl               307    it       O
# 4809   PRP                6       nsubj:pass               374    it       O
# 4848   PRP               17            nsubj               413    it       O
# 5006   PRP                3            nsubj               571    it       O
# 5120   PRP               38       nsubj:pass               685    it       O
# 5353   PRP                9            nsubj               918    it       O
# 5363   PRP                8            nsubj               928    it       O
# 5496   PRP               17              obj              1061    it       O
# 5910   PRP                8            nsubj                 7    it       O
# 5934   PRP                6            nsubj                31    it       O
# 6084   PRP               21            nsubj                83    it       O
# 6504   PRP                6              obl               281    it       O
# 6509   PRP               17            nsubj               286    it       O
# 7054   PRP               27              obl               831    it       O
# 7348   PRP                5             expl              1125    it       O
# 7535   PRP               11              obj                44    it       O
# 7561   PRP               41            nsubj                70    it       O
# 7796   PRP               10            nsubj               305    it       O
# 7902   PRP                4       nsubj:pass               411    it       O
# 8724   PRP               12              obj               107    it       O
# 8742   PRP               18            nsubj               125    it       O
# 9023   PRP               13       nsubj:pass               406    it       O
# 9041   PRP               12             expl               424    it       O
# 9069   PRP               18            nsubj               452    it       O
# 9083   PRP                6             expl               466    it       O
# 9128   PRP               31              obl               511    it       O
# 9132   PRP                6             expl               515    it       O
# 9167   PRP               10            nsubj               550    it       O
# 10044  PRP                7            nsubj                 6    it       O
# ...    ...              ...              ...               ...   ...     ...
# 21602  PRP                7            nsubj                 5    it       O
# 22255  PRP                4            nsubj               103    it       O
# 22257  PRP                6            nsubj               105    it       O
# 22326  PRP               19            nsubj               174    it       O
# 22760  PRP               15              obj               425    it       O
# 23227  PRP               35            nsubj                87    it       O
# 23271  PRP               37            nsubj               131    it       O
# 23359  PRP               10             expl                 8    it       O
# 23368  PRP               16              obj                17    it       O
# 23377  PRP               25              obj                26    it       O
# 23476  PRP               18             iobj               125    it       O
# 23516  PRP               27            nsubj               165    it       O
# 23524  PRP                4            nsubj               173    it       O
# 23556  PRP                9             expl                 7    it       O
# 23611  PRP               17              obj                62    it       O
# 23920  PRP               16             expl                65    it       O
# 24167  PRP               13            nsubj               312    it       O
# 24178  PRP               22            nsubj               323    it       O
# 24407  PRP               14            nsubj               552    it       O
# 24466  PRP               18       nsubj:pass               611    it       O
# 24525  PRP               21            nsubj               670    it       O
# 24532  PRP               27            nsubj               677    it       O
# 24591  PRP                8            nsubj               736    it       O
# 25187  PRP                5            nsubj              1332    it       O
# 25200  PRP               19            nsubj              1345    it       O
# 25499  PRP               15            nsubj              1644    it       O
# 25669  PRP                5            nsubj                84    it       O
# 26666  PRP                6            nsubj                 5    it       O
# 26770  PRP               15            nsubj               109    it       O
# 26868  PRP               35              obj                73    it       O
# 27720  PRP               20            nsubj               925    it       O
# 27729  PRP               31            nsubj               934    it       O
# 27864  PRP                6            nsubj                 5    it       O
# 27896  PRP                4            nsubj                37    it       O
# 28396  PRP               15              obl               456    it       O
# 28586  PRP               22              obj               646    it       O
# 28975  PRP               17             nmod              1035    it       O
# 29214  PRP               34              obj               209    it       O
# 30219  PRP                4        parataxis               560    it       O
# 30223  PRP                1            nsubj               564    it       O
# 30230  PRP                6            nsubj               571    it       O
# 30813  PRP               36       nsubj:pass              1154    it       O
# 31082  PRP               14              obj              1423    it       O
# 31118  PRP                6            nsubj                 5    it       O
# 31125  PRP               10              obl                12    it       O
# 31406  PRP                6            nsubj               293    it       O
# 31447  PRP               10            nsubj                31    it       O
# 32469  PRP                5            nsubj               695    it       O
# 32503  PRP                3            nsubj               729    it       O
# 32571  PRP               24            nsubj               797    it       O
#
#        sentence_number  sentence_token_number token  cue_label     token_-1  \
# 127                  5                     21    it          0       before
# 210                  9                      8    it          0           if
# 966                 12                      7    it          0         lost
# 986                 13                     16    it          0        about
# 1259                27                     24    it          0       repair
# 1286                28                      2    it          0          And
# 1466                34                     35    it          0        dumps
# 1580                38                     16    it          0         flog
# 1587                38                     23    it          0           of
# 1646                41                      4    it          0    realizing
# 2398                15                     16    it          0        after
# 2405                15                     23    it          0         said
# 2528                20                     18    it          0         pare
# 2753                 9                     12    it          0            ,
# 3442                 5                     23    it          0         have
# 3696                18                     26    it          0          let
# 3735                20                     17    it          0         says
# 4005                29                     19    it          0      because
# 4503                 3                      3    it          0            ,
# 4581                 6                      2    it          0      Perhaps
# 4734                11                     18    it          0         when
# 4742                12                      3    it          0         time
# 4809                15                      4    it          0  undoubtedly
# 4848                16                     15    it          0      thought
# 5006                22                      2    it          0           As
# 5120                25                     35    it          0        until
# 5353                31                      8    it          0         that
# 5363                32                      5    it          0            ,
# 5496                37                     18    it          0      justify
# 5910                 1                      7    it          0         said
# 5934                 2                      4    it          0         said
# 6084                 3                     19    it          0            ,
# 6504                15                      8    it          0          for
# 6509                15                     13    it          0            ,
# 7054                54                     29    it          0           of
# 7348                75                      3    it          0           if
# 7535                 2                     12    it          0       making
# 7561                 2                     38    it          0           as
# 7796                10                      9    it          0         role
# 7902                15                      2    it          0         When
# 8724                 8                     13    it          0       regret
# 8742                 9                     17    it          0        where
# 9023                19                     10    it          0            ,
# 9041                20                      6    it          0            ,
# 9069                21                     16    it          0            ,
# 9083                22                      3    it          0           So
# 9128                23                     33    it          0      through
# 9132                24                      3    it          0            ,
# 9167                26                      5    it          0       thinks
# 10044                1                      6    it          0         said
# ...                ...                    ...   ...        ...          ...
# 21602                1                      5    it          0         said
# 22255                4                      3    it          0            ,
# 22257                4                      5    it          0         said
# 22326                6                     18    it          0          has
# 22760               13                     16    it          0       supply
# 23227                3                     34    it          0           as
# 23271                4                     34    it          0     believes
# 23359                1                      8    it          0         said
# 23368                1                     17    it          0        allow
# 23377                1                     26    it          0         help
# 23476                5                     19    it          0         give
# 23516                6                     23    it          0      because
# 23524                7                      3    it          0         said
# 23556                1                      7    it          0         said
# 23611                2                     18    it          0       enable
# 23920                3                     14    it          0         that
# 24167               14                     10    it          0         that
# 24178               14                     21    it          0        loans
# 24407               23                     13    it          0         that
# 24466               25                     16    it          0         that
# 24525               26                     17    it          0         said
# 24532               26                     24    it          0         that
# 24591               28                      7    it          0         said
# 25187               49                      4    it          0         said
# 25200               49                     17    it          0         when
# 25499               60                     11    it          0           as
# 25669                4                      3    it          0            ,
# 26666                1                      5    it          0         said
# 26770                6                     14    it          0         said
# 26868                2                     36    it          0      driving
# 27720               30                     18    it          0         that
# 27729               30                     27    it          0      decided
# 27864                1                      5    it          0         said
# 27896                3                      3    it          0         said
# 28396               19                      9    it          0         like
# 28586               25                     23    it          0      causing
# 28975               41                     19    it          0          for
# 29214                7                     35    it          0     adopting
# 30219               24                      8    it          0          n't
# 30223               25                      2    it          0       Indeed
# 30230               26                      5    it          0   repeatedly
# 30813               45                     33    it          0           --
# 31082               57                     15    it          0         work
# 31118                1                      5    it          0         said
# 31125                1                     12    it          0      against
# 31406               13                      4    it          0         said
# 31447                2                      9    it          0         said
# 32469               23                      2    it          0           If
# 32503               24                      2    it          0           If
# 32571               26                     23    it          0           if
#
#            token_-2       token_-3       token_-4         token_-5  \
# 127               ,        session             's           Friday
# 210               ,        deficit            the               of
# 966             has            she              ,               is
# 986           blabs       Michelle              ,            world
# 1259             or          clean             to             time
# 1286              .           lock            the               in
# 1466            and            car            his           steals
# 1580             to      producers             ''               's
# 1587        version  Yank-oriented              a               or
# 1646        without        Perhaps              .      antecedents
# 2398            bid       takeover          -RRB-          billion
# 2405            but              ,      extension              the
# 2528          would           that  restructuring         sweeping
# 2753     incentives        without              ,            where
# 3442           will           that           Bloc             East
# 3696            has        Maxwell         Robert               's
# 3735          staff             's        network              the
# 4005        loyalty         Europe           Free            Radio
# 4503         Rather              .        service         national
# 4581              ?           back         coming             keep
# 4734              ,            ago          years               of
# 4742           This              .          loose              let
# 4809              ,           Thus              .           option
# 4848         surely              ,           plan              the
# 5006              .       families     supporting          perhaps
# 5120         burner           back            the               on
# 5353           weak             so         sector        voluntary
# 5363       contrary            the             On                ?
# 5496             to            try           then              and
# 5910           Inc.          Group        Service       Physicians
# 5934     Physicians       American              .             Corp
# 6084           year            the             of             rest
# 6504            pay            n't             wo           market
# 6509          argue           they              ,               it
# 7054           much             do            can           skills
# 7348           Even              .           them               on
# 7535              ,     telephones            the               on
# 7561              ,         system        banking              the
# 7796           same            the         assume               to
# 7902              .           said             he               ''
# 8724             to          lived           1987               of
# 8742          above              %             48              was
# 9023           says          Front            Mr.                ,
# 9041           hand          other            the               On
# 9069            run             to         starts          emotion
# 9083             ``              .           said               he
# 9128           ride           just             to               be
# 9132      Generally              .             it          through
# 9167           also             he            But               ''
# 10044         Group     Commercial         Banker         Coldwell
# ...             ...            ...            ...              ...
# 21602          Inc.       Computer          Apple                .
# 22255         Still              .        earlier             year
# 22257            it              ,          Still                .
# 22326           nor              ,           1989               of
# 22760            to      operation        casting               's
# 23227            ''              ,           chip          talking
# 23271   Instruments          Texas            but               --
# 23359             ,         Dallas              ,            Corp.
# 23368            to          court     bankruptcy             U.S.
# 23377            to            Co.          &amp;           Freres
# 23476            to             24          Sept.             Code
# 23516        banker     investment             's            Lomas
# 23524            It              .       creditor                a
# 23556      Commerce             of           Bank         Imperial
# 23611      earnings         strong             's             bank
# 23920           now              ,          deals            fewer
# 24167        Friday      announced            UAL              buy
# 24178          bank             in        billion              7.2
# 24407     yesterday           said              ,            maker
# 24466            be            may           deal     Vitro-Anchor
# 24525     Donaldson              ,           debt         existing
# 24532            ''      confident         highly               ``
# 24591             ,      meanwhile              ,          Pacific
# 25187           has         Ramada              .             1\/2
# 25200     indicated            n't            has              but
# 25499     bolstered              ,          whole                a
# 25669  Specifically              .    perspective              new
# 26666         Corp.     Industrial          Kysor                .
# 26770             ,      equipment  refrigeration       commercial
# 26868           and              ,    Association             Loan
# 27720       meeting            the             of             time
# 27729           but              ,       improper               be
# 27864          Inc.     Industries        Trinity                .
# 27896       Trinity              .        million               40
# 28396             ,          years            few             next
# 28586             ,       industry          local              the
# 28975      exchange        foreign             of            short
# 29214           for  justification             ''       reasonable
# 30219            is              ,        problem              the
# 30223            ''              ?             it              n't
# 30230          said            has       Congress                .
# 30813            ''   Moonlighting             ``    crime\/comedy
# 31082            to        studios            and         networks
# 31118          Inc.      Equipment    Recognition                .
# 31125         filed         action          civil                a
# 31406       company            The              .            since
# 31447             ,          maker       computer              and
# 32469             .      emergency             of            state
# 32503             .         unrest            and  disillusionment
# 32571             ;       violence            and         protests
#
#          token_+1     token_+2        token_+3        token_+4     token_+5  \
# 127           got      started              on             its     reckless
# 210          were     combined            with               a   stubbornly
# 966          just           as         quickly               .       Rather
# 986            to            a        sandwich             man        while
# 1259            ;          the         beat-up         vehicle          can
# 1286        takes       Declan               ,             the   obligatory
# 1466           in       Dieppe               .              In    producing
# 1580            ,           or               a   Yank-oriented      version
# 1587            ,           in         America               .       Thames
# 1646            ,          Mr.         Taffner  simultaneously          has
# 2398     received          the       extension               ,          but
# 2405        would       launch               a             new          bid
# 2528           to            a         tobacco             and    financial
# 2753           's            a           tough          market            ,
# 3442            .          But             the           rapid      changes
# 3696           be        known            here            that           he
# 3735        still          has          plenty              to           do
# 4005          was  responsible              in            many         ways
# 4503           is         born              of     frustration         with
# 4581           is      because         utopian       nostalgia       evokes
# 4734        again          was             let           loose            .
# 4742    attempted           to          invade             two    connected
# 4809          was        hoped            that             the          new
# 4848        might         help             the           party           to
# 5006     happened            ,       political      resistance    developed
# 5120          can           be         brought         forward          and
# 5353        needs         such     unsolicited      assistance            ?
# 5363           is           as          robust              as         ever
# 5496           by     creating               a              GI         Bill
# 5910    purchased        about              42               %           of
# 5934         also     replaced            four           Texas     American
# 6084        would        leave             GDP          growth          for
# 6504            ,         they           argue               ,           it
# 6509           ca          n't              be           worth          its
# 7054         well           --             but             not      cheaply
# 7348           is      cheaper              to           build  playgrounds
# 7535        clear           to       officials              in          the
# 7561          did           in         October            1987            ,
# 7796       played           in         October            1987            ,
# 7902          was    suggested             his         comment          was
# 8724            .         Even           after          Friday           's
# 8742       landed           on            Oct.              19          two
# 9023        would           be       misguided              to         sell
# 9041           's          not     necessarily               a         good
# 9069          can          run         further            than       anyone
# 9083           's         more         prudent              to         wait
# 9128            .    Generally               ,              it           is
# 9132           is          n't            wise              to           be
# 9167           is           ``               a            good         week
# 10044        sold            $              47         million           of
# ...           ...          ...             ...             ...          ...
# 21602        will        offer            cash         rebates           on
# 22255        said           it         expects           sales          for
# 22257     expects        sales             for             all           of
# 22326        made            a        detailed        forecast           of
# 22760           ,           he            said               ,        which
# 23227    launches         into               a       15-second    discourse
# 23271          is            a           first               .     Previous
# 23359        will          ask               a            U.S.   bankruptcy
# 23368          to         hire          Lazard          Freres        &amp;
# 23377        sell          its         leasing            unit            .
# 23476  additional         time              to            work           on
# 23516          is         also               a        creditor            .
# 23524       chose       Lazard              in            part      because
# 23556        will     increase             its       loan-loss   provisions
# 23611          to           be             the           first        major
# 23920          's      tougher              to         finance         them
# 24167       could          n't         arrange             the            $
# 24178       needs           to             buy             the       parent
# 24407      agreed           to             buy          Anchor        Glass
# 24466         was          put        together            late       Friday
# 24525          is           ``          highly       confident           ''
# 24532        will           be            able              to         sell
# 24591     expects           to         arrange               $          430
# 25187       hopes           to         propose               a          new
# 25200        will           do              so               .       Shares
# 25499          is           by        takeover     speculation            ,
# 25669        must   understand             how     real-estate      markets
# 26666     expects          its   third-quarter             net     earnings
# 26770     expects          its  fourth-quarter        earnings           to
# 26868        into   insolvency               .            Fred   Wertheimer
# 27720       might         seem              to              be     improper
# 27729         was           ``        entirely     appropriate           ''
# 27864     reached            a     preliminary       agreement           to
# 27896       plans           to           begin        delivery           of
# 28396          or          not               ,           China           is
# 28586          to      tighten          credit        policies          and
# 28975          to       hamper      production              in    Guangdong
# 29214           .         That              is               a         much
# 30219           ?           ''          Indeed              it           is
# 30223          is            .        Congress             has         said
# 30230       wants           no            part              of          the
# 30813          is          n't         allowed              to        share
# 31082         out           on           their             own            .
# 31118     settled            a           civil          action        filed
# 31125          by          the         federal      government           on
# 31406        will     continue              to          pursue            a
# 31447         had          net              of               $           72
# 32469        does          n't           yield              on        these
# 32503        does            ,             the           large       number
# 32571        does            ,        Pretoria            will          use
#
#           lemma_-1      lemma_-2       lemma_-3       lemma_-4  \
# 127         before             ,        session             's
# 210             if             ,        deficit            the
# 966           lose          have            she              ,
# 986          about          blab       Michelle              ,
# 1259        repair            or          clean             to
# 1286           and             .           lock            the
# 1466         dumps           and            car             he
# 1580          flog            to       producer             ''
# 1587            of       version    yank-orient              a
# 1646       realize       without        perhaps              .
# 2398         after           bid       takeover          -rrb-
# 2405           say           but              ,      extension
# 2528          pare         would           that  restructuring
# 2753             ,     incentive        without              ,
# 3442          have          will           that           Bloc
# 3696           let          have        Maxwell         Robert
# 3735           say         staff             's        network
# 4005       because       loyalty         Europe           free
# 4503             ,        Rather              .        service
# 4581       perhaps             ?           back           come
# 4734          when             ,            ago           year
# 4742          time          this              .          loose
# 4809   undoubtedly             ,           thus              .
# 4848         think        surely              ,           plan
# 5006            as             .         family        support
# 5120         until        burner           back            the
# 5353          that          weak             so         sector
# 5363             ,      contrary            the             on
# 5496       justify            to            try           then
# 5910           say          Inc.          Group        Service
# 5934           say    Physicians       american              .
# 6084             ,          year            the             of
# 6504           for           pay            not           will
# 6509             ,         argue           they              ,
# 7054            of          much             do            can
# 7348            if          even              .           they
# 7535          make             ,      telephone            the
# 7561            as             ,         system        banking
# 7796          role          same            the         assume
# 7902          when             .            say             he
# 8724        regret            to           live           1987
# 8742         where         above              %             48
# 9023             ,           say          Front            Mr.
# 9041             ,          hand          other            the
# 9069             ,           run             to          start
# 9083            so            ``              .            say
# 9128       through          ride           just             to
# 9132             ,     generally              .             it
# 9167         think          also             he            but
# 10044          say         Group     Commercial         Banker
# ...            ...           ...            ...            ...
# 21602          say          Inc.       Computer          Apple
# 22255            ,         still              .        earlier
# 22257          say            it              ,          still
# 22326         have           nor              ,           1989
# 22760       supply            to      operation        casting
# 23227           as            ''              ,           chip
# 23271      believe    instrument          Texas            but
# 23359          say             ,         Dallas              ,
# 23368        allow            to          court     bankruptcy
# 23377         help            to            Co.          &amp;
# 23476         give            to             24          Sept.
# 23516      because        banker     investment             's
# 23524          say            it              .       creditor
# 23556          say      Commerce             of           Bank
# 23611       enable       earning         strong             's
# 23920         that           now              ,           deal
# 24167         that        Friday       announce            UAL
# 24178         loan          bank             in        billion
# 24407         that     yesterday            say              ,
# 24466         that            be            may           deal
# 24525          say     Donaldson              ,           debt
# 24532         that            ''      confident         highly
# 24591          say             ,      meanwhile              ,
# 25187          say          have         Ramada              .
# 25200         when      indicate            not           have
# 25499           as       bolster              ,          whole
# 25669            ,  specifically              .    perspective
# 26666          say         Corp.     Industrial          Kysor
# 26770          say             ,      equipment  refrigeration
# 26868        drive           and              ,    Association
# 27720         that       meeting            the             of
# 27729       decide           but              ,       improper
# 27864          say          Inc.     Industries        Trinity
# 27896          say       Trinity              .        million
# 28396         like             ,           year            few
# 28586        cause             ,       industry          local
# 28975          for      exchange        foreign             of
# 29214        adopt           for  justification             ''
# 30219          not            be              ,        problem
# 30223       indeed            ''              ?             it
# 30230   repeatedly           say           have       Congress
# 30813           --            ''   moonlighting             ``
# 31082         work            to         studio            and
# 31118          say          Inc.      equipment    recognition
# 31125      against          file         action          civil
# 31406          say       company            the              .
# 31447          say             ,          maker       computer
# 32469           if             .      emergency             of
# 32503           if             .         unrest            and
# 32571           if             ;       violence            and
#
#               lemma_-5    lemma_+1     lemma_+2        lemma_+3  \
# 127             Friday         get        start              on
# 210                 of          be      combine            with
# 966                 be        just           as         quickly
# 986              world          to            a        sandwich
# 1259              time           ;          the         beat-up
# 1286                in        take       Declan               ,
# 1466             steal          in       Dieppe               .
# 1580                's           ,           or               a
# 1587                or           ,           in         America
# 1646        antecedent           ,          Mr.         Taffner
# 2398           billion     receive          the       extension
# 2405               the       would       launch               a
# 2528          sweeping          to            a         tobacco
# 2753             where          be            a           tough
# 3442              East           .          but             the
# 3696                's          be         know            here
# 3735               the       still         have          plenty
# 4005             Radio          be  responsible              in
# 4503          national          be         bear              of
# 4581              keep          be      because         utopian
# 4734                of       again           be             let
# 4742               let     attempt           to          invade
# 4809            option          be         hope            that
# 4848               the       might         help             the
# 5006           perhaps      happen            ,       political
# 5120                on         can           be           bring
# 5353         voluntary        need         such     unsolicited
# 5363                 ?          be           as          robust
# 5496               and          by       create               a
# 5910        Physicians    purchase        about              42
# 5934              Corp        also      replace            four
# 6084              rest       would        leave             gdp
# 6504            market           ,         they           argue
# 6509                it         can          not              be
# 7054             skill        well           --             but
# 7348                on          be      cheaper              to
# 7535                on       clear           to        official
# 7561               the          do           in         October
# 7796                to        play           in         October
# 7902                ''          be      suggest              he
# 8724                of           .         even           after
# 8742                be        land           on            Oct.
# 9023                 ,       would           be         misguid
# 9041                on          be          not     necessarily
# 9069           emotion         can          run         further
# 9083                he          be         more         prudent
# 9128                be           .    generally               ,
# 9132           through          be          not            wise
# 9167                ''          be           ``               a
# 10044         Coldwell        sell            $              47
# ...                ...         ...          ...             ...
# 21602                .        will        offer            cash
# 22255             year         say           it          expect
# 22257                .      expect         sale             for
# 22326               of        make            a        detailed
# 22760               's           ,           he             say
# 23227          talking      launch         into               a
# 23271               --          be            a           first
# 23359            Corp.        will          ask               a
# 23368             U.S.          to         hire          Lazard
# 23377           Freres        sell          its         leasing
# 23476             code  additional         time              to
# 23516            Lomas          be         also               a
# 23524                a      choose       Lazard              in
# 23556         Imperial        will     increase             its
# 23611             bank          to           be             the
# 23920            fewer          be      tougher              to
# 24167              buy       could          not         arrange
# 24178              7.2        need           to             buy
# 24407            maker       agree           to             buy
# 24466     Vitro-Anchor          be          put        together
# 24525            exist          be           ``          highly
# 24532               ``        will           be            able
# 24591          Pacific      expect           to         arrange
# 25187             1\/2        hope           to         propose
# 25200              but        will           do              so
# 25499                a          be           by        takeover
# 25669              new        must   understand             how
# 26666                .      expect          its   third-quarter
# 26770       commercial      expect          its  fourth-quarter
# 26868             Loan        into   insolvency               .
# 27720             time       might         seem              to
# 27729               be          be           ``        entirely
# 27864                .       reach            a     preliminary
# 27896               40        plan           to           begin
# 28396             next          or          not               ,
# 28586              the          to      tighten          credit
# 28975            short          to       hamper      production
# 29214       reasonable           .         that              be
# 30219              the           ?           ''          indeed
# 30223              not          be            .        Congress
# 30230                .        want           no            part
# 30813    crime\/comedy          be          not           allow
# 31082          network         out           on            they
# 31118                .      settle            a           civil
# 31125                a          by          the         federal
# 31406            since        will     continue              to
# 31447              and        have          net              of
# 32469            state          do          not           yield
# 32503  disillusionment          do            ,             the
# 32571          protest          do            ,        Pretoria
#
#              lemma_+4    lemma_+5 POS_-1 POS_-2 POS_-3 POS_-4 POS_-5 POS_+1  \
# 127               its    reckless     IN      ,     NN    POS    NNP    VBD
# 210                 a  stubbornly     IN      ,     NN     DT     IN    VBD
# 966                 .      Rather    VBN    VBZ    PRP      ,    VBZ     RB
# 986               man       while     IN    VBZ    NNP      ,     NN     IN
# 1259          vehicle         can     VB     CC     VB     TO     NN      ,
# 1286              the  obligatory     CC      .     NN     DT     IN    VBZ
# 1466               in     produce    VBZ     CC     NN   PRP$    VBZ     IN
# 1580      yank-orient     version     VB     TO    NNS     ''    POS      ,
# 1587                .      Thames     IN     NN    VBN     DT     CC      ,
# 1646   simultaneously        have    VBG     IN     RB      .    NNS      ,
# 2398                ,         but     IN     NN     NN     NN     CD    VBD
# 2405              new         bid    VBD     CC      ,     NN     DT     MD
# 2528              and   financial     VB     MD    WDT     NN    VBG     IN
# 2753           market           ,      ,    NNS     IN      ,    WRB    VBZ
# 3442            rapid      change     VB     MD    WDT    NNP    NNP      .
# 3696             that          he    VBN    VBZ    NNP    NNP    POS     VB
# 3735               to          do    VBZ     NN    POS     NN     DT     RB
# 4005             many         way     IN     NN    NNP     JJ    NNP    VBD
# 4503      frustration        with      ,     RB      .     NN     JJ    VBZ
# 4581        nostalgia       evoke     RB      .     RB    VBG     VB    VBZ
# 4734            loose           .    WRB      ,     RB    NNS     IN     RB
# 4742              two     connect     NN     DT      .     JJ    VBN    VBD
# 4809              the         new     RB      ,     RB      .     NN    VBD
# 4848            party          to    VBD     RB      ,     NN     DT     MD
# 5006       resistance     develop     IN      .    NNS    VBG     RB    VBD
# 5120          forward         and     IN     NN     NN     DT     IN     MD
# 23368                   50                1                  I
# 23377                   41                1                  I
# 23476                   19                0                  O
# 23516                    7                1                  I
# 23524                    .                1                  B
# 23556                   48                1                  B
# 23611                   41                1                  I
# 23920                   64                0                  O
# 24167                  213                1                  I
# 24178                  202                1                  I
# 24407                  117                1                  I
# 24466                   58                0                  O
# 24525                   65                1                  B
# 24532                   58                1                  I
# 24591                   24                1                  B
# 25187                   11                1                  B
# 25200                   12                1                  I
# 25499                   42                0                  O
# 25669                    .                0                  O
# 26666                   30                1                  B
# 26770                    .                1                  B
# 26868                   17                1                  I
# 27720                   27                1                  I
# 27729                   18                1                  I
# 27864                   17                1                  B
# 27896                   17                1                  B
# 28396                   14                1                  I
# 28586                   11                1                  I
# 28975                   25                1                  I
# 29214                   23                1                  I
# 30219                   10                0                  I
# 30223                    6                0                  O
# 30230                    8                1                  B
# 30813                   36                1                  I
# 31082                   19                1                  I
# 31118                   28                1                  B
# 31125                   21                1                  I
# 31406                    .                1                  B
# 31447                  105                1                  B
# 32469                   45                0                  O
# 32503                   11                1                  O
# 32571                   20                0                  O
#
#       content_label_pred
# 127                    I
# 210                    O
# 966                    O
# 986                    O
# 1259                   O
# 1286                   O
# 1466                   O
# 1580                   O
# 1587                   O
# 1646                   O
# 2398                   I
# 2405                   B
# 2528                   I
# 2753                   I
# 3442                   I
# 3696                   O
# 3735                   B
# 4005                   I
# 4503                   O
# 4581                   O
# 4734                   O
# 4742                   O
# 4809                   O
# 4848                   B
# 5006                   O
# 5120                   O
# 5353                   O
# 5363                   O
# 5496                   O
# 5910                   B
# 5934                   B
# 6084                   I
# 6504                   I
# 6509                   I
# 7054                   I
# 7348                   O
# 7535                   O
# 7561                   I
# 7796                   O
# 7902                   O
# 8724                   O
# 8742                   O
# 9023                   I
# 9041                   O
# 9069                   I
# 9083                   I
# 9128                   I
# 9132                   I
# 9167                   B
# 10044                  B
# ...                  ...
# 21602                  B
# 22255                  O
# 22257                  B
# 22326                  O
# 22760                  O
# 23227                  O
# 23271                  B
# 23359                  B
# 23368                  I
# 23377                  I
# 23476                  O
# 23516                  I
# 23524                  B
# 23556                  B
# 23611                  I
# 23920                  O
# 24167                  I
# 24178                  I
# 24407                  I
# 24466                  O
# 24525                  B
# 24532                  I
# 24591                  B
# 25187                  B
# 25200                  I
# 25499                  O
# 25669                  O
# 26666                  B
# 26770                  B
# 26868                  I
# 27720                  I
# 27729                  I
# 27864                  B
# 27896                  B
# 28396                  I
# 28586                  I
# 28975                  I
# 29214                  O
# 30219                  I
# 30223                  O
# 30230                  B
# 30813                  O
# 31082                  I
# 31118                  B
# 31125                  I
# 31406                  B
# 31447                  B
# 32469                  O
# 32503                  O
# 32571                  O
#
# [145 rows x 73 columns]

# %% [markdown]
# ### Part 0: Analysis of Sources: Are they NEs?

# %%
pos_dict = defaultdict(int)
count = 0
for token, pos, attribution, relevant_ne in zip(df["token"], df["POS"], df["attribution"], df["relevant_ne"]):
    source = False
    att_list = attribution.split(" ")
    for att in att_list:
        att_split = att.split("-")
        if att_split[0] not in {"_", "0", ""} and att_split[1] == "SOURCE":
            count +=1
            if relevant_ne == 0:
                pos_dict[pos] += 1

# %%
ne_count = 0
non_ne = 0
for token, pos, attribution, ne_info in zip(df["token"], df["POS"], df["attribution"], df["ne_info"]):
    source = False
    att_list = attribution.split(" ")
    for att in att_list:
        att_split = att.split("-")
        if att_split[0] not in {"_", "0", ""} and att_split[1] == "SOURCE":
            if ne_info != "O":
                ne_count +=1
            else:
                non_ne += 1

# %% [markdown]
# #### Analysis:
#
# Note that this is all at the token level - so when I say "number of sources" I mean "number of tokens that appear in source spans"
#
# pos_dict is a dict of the POS of sources that are NOT relevant NEs.
#
# count is the total number of sources.
#
# ne_count is the number of sources that are NEs (both relevant and other).
#
# non_ne is the number of sources that are NOT NEs of any type.

# %%
print(f"Total sources that are not relevant NEs: {sum(pos_dict.values())}")
print(f"Total sources: {count}")
print(f"Total sources that are any type of NE: {ne_count}")
print(f"Total sources that are NOT any type of NE: {non_ne}")
print(f"Total sources that are pronouns: {pos_dict['PRP']+pos_dict['PRP$']}")
# Out:
# Total sources that are not relevant NEs: 37777
# Total sources: 60513
# Total sources that are any type of NE: 23845
# Total sources that are NOT any type of NE: 36668
# Total sources that are pronouns: 3570

# %%
pos_dict
# Out:
# defaultdict(int,
#             {'NNS': 3425,
#              'DT': 5403,
#              'NN': 8608,
#              'PRP': 3406,
#              'IN': 3491,
#              'POS': 550,
#              'NNP': 3010,
#              ',': 4077,
#              'JJ': 2224,
#              'JJR': 40,
#              'RB': 216,
#              'VBN': 298,
#              'WDT': 225,
#              'CC': 625,
#              'CD': 536,
#              'VBG': 213,
#              'VBZ': 222,
#              'WP': 368,
#              'VBD': 171,
#              'VBP': 52,
#              'PRP$': 164,
#              'JJS': 86,
#              'NNPS': 58,
#              '``': 21,
#              "''": 27,
#              'TO': 47,
#              'VB': 70,
#              '$': 35,
#              'RBR': 6,
#              'RBS': 21,
#              '.': 10,
#              'WRB': 11,
#              'PDT': 13,
#              'MD': 16,
#              'WP$': 17,
#              ':': 1,
#              'HYPH': 2,
#              'RP': 10,
#              'UH': 2})

# %%
total_pos_dict = defaultdict(int)
for pos in df["POS"]:
    total_pos_dict[pos]+=1

# %%
total_pos_dict["NNP"]
# Out:
# 102182

# %% [markdown]
# #### Conclusion:
# It is NOT enough by a long shot to only consider NEs and pronouns as candidate sources (~34000/60513 tokens in source spans, about 55%, are NOT relevant NEs or pronouns.)

# %% [markdown]
# ### Part 1: Candidate Mention Detection
# This happens at the token/phrase level; ideally we have IOB spans that can be collapsed into symbols in later steps.

# %%
# Step 1: Content in sentence label

# %%
def content_in_sentence(df):
    '''
    Takes a df with "attribution", "filename", and "sentence_number" columns and returns a list (column) of binary
    "sentence contains a content" labels
    '''
    sent_with_content = set()
    for filename, sentence_number, attribution in zip(df["filename"], df["sentence_number"], df["attribution"]):
        for att in attribution.split(" "):
            att_split = att.split("-")
            if att_split[0] not in {"_", "0", ""} and att_split[1] == "CONTENT":
                sent_with_content.add((filename, sentence_number))
    labels = []
    for filename, sentence_number in zip(df["filename"], df["sentence_number"]):
        if (filename, sentence_number) in sent_with_content:
            label = 1
        else:
            label = 0
        labels.append(label)
    return labels

# %%
content_in_sent_labels = content_in_sentence(df)

# %%
df["content_in_sent"] = content_in_sent_labels

# %%
# Step 2: count sources in content sentences

# %%
content_in_sent_count = 0
for token, pos, attribution, content_in_sent_label in zip(df["token"], df["POS"], df["attribution"], df["content_in_sent"]):
    source = False
    att_list = attribution.split(" ")
    for att in att_list:
        att_split = att.split("-")
        if att_split[0] not in {"_", "0", ""} and att_split[1] == "SOURCE":
            if content_in_sent_label == 1:
                content_in_sent_count += 1

# %%
print(f"Number of sources that occur in sentences that contain contents: {content_in_sent_count}")
# Out:
# Number of sources that occur in sentences that contain contents: 60274

# %% [markdown]
# ##### Conclusion here: Basically all (60274/60513) sources appear in the same sentence as a content
# Note that this doesn't represent sources that appear in the same sentence as their content, necessarily.
#
# It does mean that only considering tokens/spans that appear in the same sentence as a content is a good way to determine candidate sources.

# %%
pos_candidate_dict = {"NN":[0,0], "NNS":[0,0], "NNP":[0,0], "PRP":[0,0]}
for token, pos, attribution, label in zip(df["token"], df["POS"], df["attribution"], df["content_in_sent"]):
    source = False
    att_list = attribution.split(" ")
    if pos in {"NN", "NNS", "NNP", "PRP"} and label == 1:
        source = False
        for att in att_list:
            att_split = att.split("-")
            if att_split[0] not in {"_", "0", ""} and att_split[1] == "SOURCE":
                pos_candidate_dict[pos][0] +=1
                source = True
        pos_candidate_dict[pos][1] += 1

# %% [markdown]
# This dictionary represents the occurrence of POS's in sentences with contents.
# The first number is a count of the POS AS A SOURCE in such sentences, and the second is the total count of the POS in such sentences.

# %%
pos_candidate_dict
# Out:
# {'NN': [8810, 61333],
#  'NNS': [3492, 26404],
#  'NNP': [22681, 42763],
#  'PRP': [3402, 11974]}

# %% [markdown]
# ##### Conclusion here: Probably viable to use these POS in sentences with content as candidate mentions; we'll have a ~25% positive example ratio, and we should get nearly all mentions.
#
# The next valuable step would be to determine the number of sources covered at least partially (as in, not necessarily whole span) by such POS's. The numbers to this point are entirely token-based (not overall source span based).

# %% [markdown]
# ### Part 2: Collapsing/Anonymizing Contents and Sources
# The goal here is to take content and source spans and convert them into symbols.
#
# The complication is that we need to keep working with DFs, and it'll be hard to collapse portions of a column or two and maintain the other columns.
#
# I need to decide what info needs to come out of this. That comes down to two things: i) the rest of this classifier (what is needed for the feature engineering?), and ii) evaluation: we can evaluate based on the labels we concoct, but what about at the level of the source-contents we're provided? Ideally we'll use the eval script from Roser, but that makes this conversion too and from our classifier DF really challenging.

# %% [markdown]
# Ideally, there's a pandas functionality that lets me preserve index nums as I collapse the DF so they can be put back.
#
# There is, of course, the "filename" and "doc_token_number" columns to work with; in converting back to eval mode these can be all the difference.
#
# The other question is how do I deal with multi-part contents/spans? Where do I put them, and how on Earth do I convert them back? I probably need to keep information on the original location of these spans before I collapse them entirely. Maybe a "CONTENT-(span1)\_(span2)\_..." kind of label
