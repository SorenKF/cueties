# %%
import pandas as pd
import instance_generation
import  content_source_feats

# %%
filepath = "C:/Users/Ellie\Documents/MASTERS/NLP/Project/parc_features/parc_features/parc_train_features.tsv"

# %%
token_df = pd.read_csv(filepath, delimiter='\t', index_col=0)

# %%
instance_output = instance_generation.collect_instances_main(df)

# %%
def seperate_instance_gold(instance_output):
    
    gold_label_list = list()
    pair_list = list()
    for instance_list in instance_output:
        gold_label_list.append(instance_list[2])
        pair_tupel = (instance_list[0], instance_list[1])
        pair_list.append(pair_tupel)

    #print(gold_label_list[:4])
    #print(pair_list[:4])
    
    return pair_list, gold_label_list

# %%
seperated = seperate_instance_gold(instance_output)

# %%
pair_list = seperated[0]
gold_label_list= seperated[1]

# %%
print(pair_list[:4])
#for source, content in pair_list[:4]:
    #print(source)
print(len(pair_list))
# Out:
# [((58, 59), (57, 89)), ((60, 61), (57, 89)), ((65, 68), (57, 89)), ((72, 73), (57, 89))]
# 105855

# %%
def create_pair_df(pair_list, df):
    
    source_list = list()
    content_list = list()
    
    for source, content in pair_list:
        source_range_list = list()
        content_range_list = list()
        
        for source_index in range(source[0], source[1]+1):
            source_range_list.append(source_index)
            
        for content_index in range(content[0], content[1]+1):
            content_range_list.append(content_index)
            
        
        collect_source_lemma = list()
        for item in source_range_list:
            collect_source_lemma.append(df.loc[item,'lemma'])
            source_list.append(collect_source_lemma)
            
        
        collect_content_lemma = list()
        for item in content_range_list:
            collect_content_lemma.append(df.loc[item, 'lemma'])
            content_list.append(collect_content_lemma)
        

    main_list = list(zip(source_list,content_list ))  
    pair_df = pd.DataFrame(main_list, columns = ['item1_lemma', 'item2_lemma'])
    
    return pair_df

# %%
pair_df = create_pair_df(pair_list,token_df)
# Out:
# 256882
# 2040634
# 256882

# %%
pair_df
# Out:
#                             item1_lemma  \
# 0                            [form, of]
# 1                            [form, of]
# 2                       [asbesto, once]
# 3                       [asbesto, once]
# 4       [Kent, cigarette, filter, have]
# 5       [Kent, cigarette, filter, have]
# 6       [Kent, cigarette, filter, have]
# 7       [Kent, cigarette, filter, have]
# 8                      [percentage, of]
# 9                      [percentage, of]
# 10               [cancer, death, among]
# 11               [cancer, death, among]
# 12               [cancer, death, among]
# 13                          [group, of]
# 14                          [group, of]
# 15                     [worker, expose]
# 16                     [worker, expose]
# 17                           [it, more]
# 18                           [it, more]
# 19                          [year, ago]
# 20                          [year, ago]
# 21                 [researcher, report]
# 22                 [researcher, report]
# 23                  [asbesto, fiber, ,]
# 24                  [asbesto, fiber, ,]
# 25                  [asbesto, fiber, ,]
# 26                     [crocidolite, ,]
# 27                     [crocidolite, ,]
# 28                          [it, enter]
# 29                          [it, enter]
# ...                                 ...
# 256852                 [business, will]
# 256853                  [Mr., Sim, say]
# 256854                  [Mr., Sim, say]
# 256855                  [Mr., Sim, say]
# 256856               [Mr., Sim, figure]
# 256857               [Mr., Sim, figure]
# 256858               [Mr., Sim, figure]
# 256859                       [it, will]
# 256860                       [it, will]
# 256861          [Barry, Wright, around]
# 256862          [Barry, Wright, around]
# 256863          [Barry, Wright, around]
# 256864                         [he, be]
# 256865                         [he, be]
# 256866                     [driver, 's]
# 256867                     [driver, 's]
# 256868                        [seat, .]
# 256869                        [seat, .]
# 256870                       [he, come]
# 256871                       [he, come]
# 256872                          [I, do]
# 256873                          [I, do]
# 256874                      [power, to]
# 256875                      [power, to]
# 256876                          [I, do]
# 256877                          [I, do]
# 256878                       [today, ,]
# 256879                       [today, ,]
# 256880                        [he, say]
# 256881                        [he, say]
#
#                                               item2_lemma s/c_distance
# 0       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 1       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 2       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 3       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 4       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 5       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 6       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 7       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 8       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 9       [a, form, of, asbesto, once, use, to, make, Ke...            X
# 10      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 11      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 12      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 13      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 14      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 15      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 16      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 17      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 18      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 19      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 20      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 21      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 22      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 23      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 24      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 25      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 26      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 27      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 28      [a, form, of, asbesto, once, use, to, make, Ke...            X
# 29      [a, form, of, asbesto, once, use, to, make, Ke...            X
# ...                                                   ...          ...
# 256852  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256853  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256854  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256855  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256856  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256857  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256858  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256859  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256860  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256861  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256862  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256863  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256864  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256865  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256866  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256867  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256868  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256869  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256870  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256871  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256872  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256873  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256874  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256875  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256876  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256877  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256878  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256879  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256880  [that, the, Wall, Street, Journal, use, 220,00...            X
# 256881  [that, the, Wall, Street, Journal, use, 220,00...            X
#
# [256882 rows x 3 columns]

# %%
def create_instance_list(list_of_tuples,df):
    main_list = list()

    # Loop through instances meaning content and source span indices
    for instance in pair_list:
        # initiate instance_list and index_list
        attribution_indices = list()

        source, content = instance
        b_source, e_source = source
        b_content, e_content = content

        # For index of source
        for index in range(b_source, e_source+1):  
            attribution_indices.append(index)
        # for index of content
        for index in range(b_content, e_content+1):
            attribution_indices.append(index)
            
        # Find gap indices
        if b_source < b_content: 
            # If content follows source, gap is between last token of source and first of content
            gap_indices = [e_source, b_content]
        else:
            # If source follows content, then visa versa
            gap_indices = [e_content, b_source]

        list_tuple = (attribution_indices, gap_indices)
        main_list.append(list_tuple)
        
    return main_list

# %%
main_list = create_instance_list(pair_list, token_df)

# %%
print(len(main_list))
# Out:
# 105855

# %%
def find_sc_dist(pair_df, main_list):
    
    pair_df['s/c_distance'] = 'X'
    
    dist_list = list()
    
    for list_tuple in main_list:
        instance_list = list_tuple[0]
        
        
        if instance_list[0] < instance_list[1]:
            distance = instance_list[1] - instance_list[0]
        else:
            distance = instance_list[0] - instance_list[1]
            
        dist_list.append(distance)
        

    pair_df['s/c_distance'] = dist_list

    #return pair_df

# %%
find_sc_dist(pair_df, main_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-dc8ff915696b> in <module>
# ----> 1 find_sc_dist(pair_df, main_list)
#
# <ipython-input-70-7fb9dcbcf738> in find_sc_dist(pair_df, main_list)
#      17
#      18
# ---> 19     pair_df['s/c_distance'] = dist_list
#      20
#      21     return pair_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
def find_num_conts_between(pair_df, main_list):
    
    pair_df['num_conts_between'] = 'X'
    count_list = list()
    
    for list_tupel in main_list:
        instance_list = list_tupel[0]
        index_list = list_tupel[1]
        
        counter = 0
        for index in list(range(instance_list[0], instance_list[1])):
            if df.loc[index,'content_label_gold'] == 'B':
                counter += 1
        count_list.append(counter)
        
    #print(len(count_list))    
                
    pair_df['num_conts_between'] = counter
        
    #return df

# %%
find_num_conts_between(pair_df, main_list)
# Out:
# 105855

# %%
def find_num_sources_between(pair_df, main_list):
    
    pair_df['num_sources_between'] = 'X'
    count_list = list()
    
    for list_tupel in main_list:
        instance_list = list_tupel[0]
        index_list = list_tupel[1]
        
        counter = 0
        for index in list(range(instance_list[0], instance_list[1])):
            # TODO: Q changed from candidate_source to candidate_source_label. Check with Ellie if correct
            if df.loc[index,'candidate_source_label'] == 'B':
                counter += 1
            count_list.append(counter)
                
    df['num_sources_between'] = count_list
    #print(len(count_list))
        
    #return df

# %%
find_num_sources_between(pair_df, main_list)
# Out:
# 105855
