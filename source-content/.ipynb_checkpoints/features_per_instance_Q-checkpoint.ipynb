# %%
import pandas as pd
import instance_generation
import  content_source_feats

# %%
filepath = "C:/Users/Ellie\Documents/MASTERS/NLP/Project/parc_features/parc_features/parc_train_features.tsv"

# %%
df = pd.read_csv(filepath, delimiter='\t', index_col=0)
# Out:
# C:\Users\Ellie\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
instance_output = instance_generation.collect_instances_main(df)

# %%
def seperate_instance_gold(instance_output):
    
    gold_label_list = list()
    pair_list = list()
    for instance_list in instance_output:
        gold_label_list.append(instance_list[2])
        pair_tupel = (instance_list[0], instance_list[1])
        pair_list.append(pair_tupel)

    #print(gold_label_list[:4])
    #print(pair_list[:4])
    
    return pair_list, gold_label_list

# %%
seperated = seperate_instance_gold(instance_output)

# %%
pair_list = seperated[0]
gold_label_list= seperated[1]

# %%
print(pair_list[:4])
for source, content in pair_list[:4]:
    #print(source)
# Out:
# [((58, 59), (57, 89)), ((60, 61), (57, 89)), ((65, 68), (57, 89)), ((72, 73), (57, 89))]
# (58, 59)
# (60, 61)
# (65, 68)
# (72, 73)

# %%
def create_pair_df(pair_list, df):
    
    source_list = list()
    content_list = list()
    
    for source, content in pair_list:
        source_range_list = list()
        content_range_list = list()
        
        for source_index in range(source[0], source[1]+1):
            source_range_list.append(source_index)
            
        for content_index in range(content[0], content[1]+1):
            content_range_list.append(content_index)
            
        
        collect_source_lemma = list()
        for item in source_range_list:
            collect_source_lemma.append(df.loc[item,'lemma'])
            source_list.append(collect_source_lemma)
            
        
        collect_content_lemma = list()
        for item in content_range_list:
            collect_content_lemma.append(df.loc[item, 'lemma'])
            content_list.append(collect_content_lemma)
        
        
    main_list = list(zip(source_list,content_list ))
        
    pair_df = pd.DataFrame(main_list, columns = ['item1_lemma', 'item2_lemma'])
    
    return pair_df

# %%
create_pair_df(pair_list,df)
# Out:
#                             item1_lemma  \
# 0                            [form, of]
# 1                            [form, of]
# 2                       [asbesto, once]
# 3                       [asbesto, once]
# 4       [Kent, cigarette, filter, have]
# 5       [Kent, cigarette, filter, have]
# 6       [Kent, cigarette, filter, have]
# 7       [Kent, cigarette, filter, have]
# 8                      [percentage, of]
# 9                      [percentage, of]
# 10               [cancer, death, among]
# 11               [cancer, death, among]
# 12               [cancer, death, among]
# 13                          [group, of]
# 14                          [group, of]
# 15                     [worker, expose]
# 16                     [worker, expose]
# 17                           [it, more]
# 18                           [it, more]
# 19                          [year, ago]
# 20                          [year, ago]
# 21                 [researcher, report]
# 22                 [researcher, report]
# 23                  [asbesto, fiber, ,]
# 24                  [asbesto, fiber, ,]
# 25                  [asbesto, fiber, ,]
# 26                     [crocidolite, ,]
# 27                     [crocidolite, ,]
# 28                          [it, enter]
# 29                          [it, enter]
# ...                                 ...
# 256852                 [business, will]
# 256853                  [Mr., Sim, say]
# 256854                  [Mr., Sim, say]
# 256855                  [Mr., Sim, say]
# 256856               [Mr., Sim, figure]
# 256857               [Mr., Sim, figure]
# 256858               [Mr., Sim, figure]
# 256859                       [it, will]
# 256860                       [it, will]
# 256861          [Barry, Wright, around]
# 256862          [Barry, Wright, around]
# 256863          [Barry, Wright, around]
# 256864                         [he, be]
# 256865                         [he, be]
# 256866                     [driver, 's]
# 256867                     [driver, 's]
# 256868                        [seat, .]
# 256869                        [seat, .]
# 256870                       [he, come]
# 256871                       [he, come]
# 256872                          [I, do]
# 256873                          [I, do]
# 256874                      [power, to]
# 256875                      [power, to]
# 256876                          [I, do]
# 256877                          [I, do]
# 256878                       [today, ,]
# 256879                       [today, ,]
# 256880                        [he, say]
# 256881                        [he, say]
#
#                                               item2_lemma
# 0       [a, form, of, asbesto, once, use, to, make, Ke...
# 1       [a, form, of, asbesto, once, use, to, make, Ke...
# 2       [a, form, of, asbesto, once, use, to, make, Ke...
# 3       [a, form, of, asbesto, once, use, to, make, Ke...
# 4       [a, form, of, asbesto, once, use, to, make, Ke...
# 5       [a, form, of, asbesto, once, use, to, make, Ke...
# 6       [a, form, of, asbesto, once, use, to, make, Ke...
# 7       [a, form, of, asbesto, once, use, to, make, Ke...
# 8       [a, form, of, asbesto, once, use, to, make, Ke...
# 9       [a, form, of, asbesto, once, use, to, make, Ke...
# 10      [a, form, of, asbesto, once, use, to, make, Ke...
# 11      [a, form, of, asbesto, once, use, to, make, Ke...
# 12      [a, form, of, asbesto, once, use, to, make, Ke...
# 13      [a, form, of, asbesto, once, use, to, make, Ke...
# 14      [a, form, of, asbesto, once, use, to, make, Ke...
# 15      [a, form, of, asbesto, once, use, to, make, Ke...
# 16      [a, form, of, asbesto, once, use, to, make, Ke...
# 17      [a, form, of, asbesto, once, use, to, make, Ke...
# 18      [a, form, of, asbesto, once, use, to, make, Ke...
# 19      [a, form, of, asbesto, once, use, to, make, Ke...
# 20      [a, form, of, asbesto, once, use, to, make, Ke...
# 21      [a, form, of, asbesto, once, use, to, make, Ke...
# 22      [a, form, of, asbesto, once, use, to, make, Ke...
# 23      [a, form, of, asbesto, once, use, to, make, Ke...
# 24      [a, form, of, asbesto, once, use, to, make, Ke...
# 25      [a, form, of, asbesto, once, use, to, make, Ke...
# 26      [a, form, of, asbesto, once, use, to, make, Ke...
# 27      [a, form, of, asbesto, once, use, to, make, Ke...
# 28      [a, form, of, asbesto, once, use, to, make, Ke...
# 29      [a, form, of, asbesto, once, use, to, make, Ke...
# ...                                                   ...
# 256852  [that, the, Wall, Street, Journal, use, 220,00...
# 256853  [that, the, Wall, Street, Journal, use, 220,00...
# 256854  [that, the, Wall, Street, Journal, use, 220,00...
# 256855  [that, the, Wall, Street, Journal, use, 220,00...
# 256856  [that, the, Wall, Street, Journal, use, 220,00...
# 256857  [that, the, Wall, Street, Journal, use, 220,00...
# 256858  [that, the, Wall, Street, Journal, use, 220,00...
# 256859  [that, the, Wall, Street, Journal, use, 220,00...
# 256860  [that, the, Wall, Street, Journal, use, 220,00...
# 256861  [that, the, Wall, Street, Journal, use, 220,00...
# 256862  [that, the, Wall, Street, Journal, use, 220,00...
# 256863  [that, the, Wall, Street, Journal, use, 220,00...
# 256864  [that, the, Wall, Street, Journal, use, 220,00...
# 256865  [that, the, Wall, Street, Journal, use, 220,00...
# 256866  [that, the, Wall, Street, Journal, use, 220,00...
# 256867  [that, the, Wall, Street, Journal, use, 220,00...
# 256868  [that, the, Wall, Street, Journal, use, 220,00...
# 256869  [that, the, Wall, Street, Journal, use, 220,00...
# 256870  [that, the, Wall, Street, Journal, use, 220,00...
# 256871  [that, the, Wall, Street, Journal, use, 220,00...
# 256872  [that, the, Wall, Street, Journal, use, 220,00...
# 256873  [that, the, Wall, Street, Journal, use, 220,00...
# 256874  [that, the, Wall, Street, Journal, use, 220,00...
# 256875  [that, the, Wall, Street, Journal, use, 220,00...
# 256876  [that, the, Wall, Street, Journal, use, 220,00...
# 256877  [that, the, Wall, Street, Journal, use, 220,00...
# 256878  [that, the, Wall, Street, Journal, use, 220,00...
# 256879  [that, the, Wall, Street, Journal, use, 220,00...
# 256880  [that, the, Wall, Street, Journal, use, 220,00...
# 256881  [that, the, Wall, Street, Journal, use, 220,00...
#
# [256882 rows x 2 columns]
